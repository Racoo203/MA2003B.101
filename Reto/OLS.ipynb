# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('dataset.csv')
data.columns
# Out:
# Index(['Date', 'Latitude', 'Longitude', 'Precipitation', 'Temperature',
#        'Relative Humidity', 'Solar Radiation', 'Atmospheric Pressure',
#        'Wind Speed', 'Wind Direction', 'PM10', 'PM2.5'],
#       dtype='object')

# %%
data.describe()
# Out:
#             Latitude      Longitude  Precipitation    Temperature  \
# count  205805.000000  205805.000000  202532.000000  201891.000000
# mean       25.713618    -100.294250       0.005351      23.394571
# std         0.071372       0.157047       0.249587      23.628900
# min        25.575383    -100.585833       0.000000   -9999.000000
# 25%        25.665280    -100.412778       0.000000      18.600000
# 50%        25.729787    -100.310028       0.000000      24.290000
# 75%        25.783331    -100.188055       0.000000      28.800000
# max        25.801940     -99.995334      67.800000     112.390000
#
#        Relative Humidity  Solar Radiation  Atmospheric Pressure  \
# count      191934.000000    198708.000000         200993.000000
# mean           54.878767        -0.442631            715.424273
# std            38.994736        77.702804              9.341355
# min         -9999.000000     -9999.000000            655.400000
# ...

# %%
data.nunique()
# Out:
# Date                    14255
# Latitude                   15
# Longitude                  15
# Precipitation             149
# Temperature              4398
# Relative Humidity         107
# Solar Radiation          1362
# Atmospheric Pressure      664
# Wind Speed                602
# Wind Direction            361
# PM10                     4006
# PM2.5                    6358
# dtype: int64

# %%
data.loc[(data == -9999).any(axis=1)]
# Out:
#                        Date   Latitude   Longitude  Precipitation  \
# 56268   2023-07-17 16:00:00  25.783331 -100.585833            0.0
# 83232   2023-05-14 06:00:00  25.600870  -99.995334            0.0
# 84576   2023-07-09 06:00:00  25.600870  -99.995334            0.0
# 85416   2023-08-13 06:00:00  25.600870  -99.995334            0.0
# 93455   2022-11-27 05:00:00  25.665280 -100.412778            0.0
# 93456   2022-11-27 06:00:00  25.665280 -100.412778            0.0
# 93624   2022-12-04 06:00:00  25.665280 -100.412778            0.0
# 96311   2023-03-26 06:00:00  25.665280 -100.412778            0.0
# 96312   2023-03-26 07:00:00  25.665280 -100.412778            0.0
# 97823   2023-05-28 06:00:00  25.665280 -100.412778            0.0
# 97824   2023-05-28 07:00:00  25.665280 -100.412778            0.0
# 97825   2023-05-28 08:00:00  25.665280 -100.412778            0.0
# 97826   2023-05-28 09:00:00  25.665280 -100.412778            0.0
# ...

# %%
target_vars = ['PM10', 'PM2.5']
# Out:
#                   Date   Latitude   Longitude  Precipitation  Temperature  \
# 0  2022-01-01 00:00:00  25.791343 -100.078176            0.0        21.65
# 1  2022-01-01 01:00:00  25.791343 -100.078176            0.0        21.21
# 2  2022-01-01 02:00:00  25.791343 -100.078176            0.0        21.21
# 3  2022-01-01 03:00:00  25.791343 -100.078176            0.0        20.44
# 4  2022-01-01 04:00:00  25.791343 -100.078176            0.0        19.80
#
#    Relative Humidity  Solar Radiation  Atmospheric Pressure  Wind Speed  \
# 0               59.0              0.0                 715.7         6.5
# 1               59.0              0.0                 715.5         7.1
# 2               62.0              0.0                 715.4         7.7
# 3               59.0              0.0                 715.1         8.2
# 4               59.0              0.0                 715.1         8.1
#
#    Wind Direction   PM10   PM2.5
# 0           285.0  142.0  111.00
# ...
